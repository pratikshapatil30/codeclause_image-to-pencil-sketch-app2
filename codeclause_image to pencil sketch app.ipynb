# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayestha/Codeclause_project_Image-to-Pencil-Sketch-App/blob/main/Codeclause_AI_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Codeclause Artificial Intelligence**

# %% [markdown]
# ## **Image to Pencil Sketch App**

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np

# %%
import matplotlib.image as mpimg

# %%
import matplotlib.pyplot as plt

# %%
import cv2
# %matplotlib inline

# %%
image = mpimg.imread('/content/codeclause.png')
plt.imshow(image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image, cmap='Greys_r')

# %%
inverted_blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
f, (ax1) = plt.subplots(1, figsize=(5,5))
ax1.set_title('inverted blurred image')
ax1.imshow(inverted_blurred, cmap='Greys_r')

# %%
final = cv2.divide(gray_image, 255 - inverted_blurred, scale=240)
plt.figure(figsize=(5,5))
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()

# %%
plt.figure(figsize=(30,30))
plt.subplot(1,5,1)
plt.imshow(image)
plt.axis("off")
plt.title("Original Image")
plt.subplot(1,5,2)
plt.imshow(gray_image, cmap="gray")
plt.axis("off")
plt.title("GrayScale Image")
plt.subplot(1,5,3)
plt.imshow(final,cmap="gray")
plt.axis("off")
plt.title("Final Sketch Image")
plt.show()
